# %%
Name = input("What is your name :")
print ("your name is:", Name)
# Out:
# What is your name : Divyang
# your name is: Divyang

# %%
a=100
b=50
c=25
total = a+b+c
print(total)
# Out:
# 175

# %%
a=10
b=10
C=a*b
print(C)
# Out:
# 100

# %%
a=10
b=20
print("Multiplication:",a*b,"Subtraction:",a-b, "Sum:",a+b, "Division:", a/b)
# Out:
# Multiplication: 200 Subtraction: -10 Sum: 30 Division: 0.5
